# %%
import math

from pyod.models import lof
from scipy.io import arff
from operator import index

import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import NearestNeighbors, KernelDensity
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import scipy.stats
from scipy.stats import expon, skew, norm,gamma, anderson,goodness_of_fit, monte_carlo_test, probplot, skewnorm
from scipy import integrate
from sklearn.metrics import auc
import seaborn as sns
import math

from statsmodels.sandbox.distributions.gof_new import kstest

plt.rcParams['figure.figsize'] = [15, 7]
import warnings
from scipy import stats
from pyod.models import abod, knn, lof, cof
warnings.filterwarnings('ignore')

# %%
arff_file = arff.loadarff(f'./semantic/Arrhythmia/Arrhythmia_withoutdupl_norm_46.arff') # import the attribute-relation file format
df4 = pd.DataFrame(arff_file[0])
X = df4.drop(columns=['outlier','id']).values
#get outlier values
y = df4['outlier'].values
le = LabelEncoder()
#encoded the variables as 0=non-outlier, 1=outlier
y = le.fit_transform(y)

clf_name = 'KNN'
clf = KNN(p=1, n_neighbors=60)
clf.fit(X)

print(roc_auc_score(y, clf.decision_scores_))
# Out:
# 0.75722186853414

# %%
arff_file = arff.loadarff(f'./semantic/Arrhythmia/Arrhythmia_withoutdupl_norm_46.arff') # import the attribute-relation file format
df4 = pd.DataFrame(arff_file[0])
X = df4.drop(columns=['outlier','id']).values
#get outlier values
y = df4['outlier'].values
le = LabelEncoder()
#encoded the variables as 0=non-outlier, 1=outlier
y = le.fit_transform(y)

clf_name = 'KNN'
clf = LOF(p=1)
clf.fit(X)

print(roc_auc_score(y, clf.decision_scores_))
# Out:
# 0.7500994747731976

# %%
folder_structure_1d = [
    "semantic/Annthyroid/Annthyroid_withoutdupl_norm_07.arff",
    "semantic/Arrhythmia/Arrhythmia_withoutdupl_norm_46.arff",
    "semantic/Cardiotocography/Cardiotocography_withoutdupl_norm_22.arff",
    "semantic/HeartDisease/HeartDisease_withoutdupl_norm_44.arff",
    "semantic/Hepatitis/Hepatitis_withoutdupl_norm_16.arff",
    "semantic/InternetAds/InternetAds_withoutdupl_norm_19.arff",
    "semantic/PageBlocks/PageBlocks_withoutdupl_norm_09.arff",
    "semantic/Parkinson/Parkinson_withoutdupl_norm_75.arff",
    "semantic/Pima/Pima_withoutdupl_norm_35.arff",
    "semantic/SpamBase/SpamBase_withoutdupl_norm_40.arff",
    "semantic/Stamps/Stamps_withoutdupl_norm_09.arff",
    "semantic/Wilt/Wilt_withoutdupl_norm_05.arff"
]

differentModels = [
    abod.ABOD,
    knn.KNN,
    lof.LOF,
    cof.COF,
]

# %%
dicts = {}
for t in folder_structure_1d:
    print(t)
    dicts[t] = {}
    arff_file = arff.loadarff(f'./{t}') # import the attribute-relation file format
    df4 = pd.DataFrame(arff_file[0])
    X = df4.drop(columns=['outlier','id']).values
    #get outlier values
    y = df4['outlier'].values
    le = LabelEncoder()
    #encoded the variables as 0=non-outlier, 1=outlier
    y = le.fit_transform(y)
    for z in differentModels:
        print(z)
        arr = []
        arr2 = []
        if z == abod.ABOD or z == cof.COF:
            clf = z(contamination=0.1)
            clf.fit(X)
            print(roc_auc_score(y, clf.decision_scores_))
            dicts[t][z] = roc_auc_score(y, clf.decision_scores_)
        else:
            for kn in range(2,70):
                clf = z(p=1, n_neighbors=kn)
                clf.fit(X)
                arr += [roc_auc_score(y, clf.decision_scores_)]
                arr2 += [kn]

            print(max(arr),arr.index(max(arr))+2)
            dicts[t][z] = [max(arr),arr.index(max(arr))+2]

df = pd.DataFrame.from_dict(dicts)
# Out:
# semantic/Annthyroid/Annthyroid_withoutdupl_norm_07.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6778645722414836
# <class 'pyod.models.knn.KNN'>
# 0.6728163431040994 2
# <class 'pyod.models.lof.LOF'>
# 0.7021573204078677 11
# <class 'pyod.models.cof.COF'>
# 0.6656762443458187
# semantic/Arrhythmia/Arrhythmia_withoutdupl_norm_46.arff
# <class 'pyod.models.abod.ABOD'>
# 0.7248328823810283
# <class 'pyod.models.knn.KNN'>
# 0.7606040108228554 43
# <class 'pyod.models.lof.LOF'>
# 0.7550135285691548 48
# <class 'pyod.models.cof.COF'>
# 0.7191429253541302
# semantic/Cardiotocography/Cardiotocography_withoutdupl_norm_22.arff
# <class 'pyod.models.abod.ABOD'>
# 0.48409699362473435
# <class 'pyod.models.knn.KNN'>
# 0.5576807887828659 69
# <class 'pyod.models.lof.LOF'>
# 0.6023545251885496 69
# <class 'pyod.models.cof.COF'>
# 0.5674741655902329
# semantic/HeartDisease/HeartDisease_withoutdupl_norm_44.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6287222222222222
# <class 'pyod.models.knn.KNN'>
# 0.6998888888888889 68
# <class 'pyod.models.lof.LOF'>
# 0.6398333333333334 69
# <class 'pyod.models.cof.COF'>
# 0.5269999999999999
# semantic/Hepatitis/Hepatitis_withoutdupl_norm_16.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6486796785304247
# <class 'pyod.models.knn.KNN'>
# 0.7898966704936854 25
# <class 'pyod.models.lof.LOF'>
# 0.8036739380022963 50
# <class 'pyod.models.cof.COF'>
# 0.5109070034443168
# semantic/InternetAds/InternetAds_withoutdupl_norm_19.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6571512624476248
# <class 'pyod.models.knn.KNN'>
# 0.722096574522501 13
# <class 'pyod.models.lof.LOF'>
# 0.7026641658050825 69
# <class 'pyod.models.cof.COF'>
# 0.6785562455787124
# semantic/PageBlocks/PageBlocks_withoutdupl_norm_09.arff
# <class 'pyod.models.abod.ABOD'>
# 0.7013070556914144
# <class 'pyod.models.knn.KNN'>
# 0.8728066159906518 69
# <class 'pyod.models.lof.LOF'>
# 0.8105893596430995 69
# <class 'pyod.models.cof.COF'>
# 0.6861323599683576
# semantic/Parkinson/Parkinson_withoutdupl_norm_75.arff
# <class 'pyod.models.abod.ABOD'>
# 0.625141723356009
# <class 'pyod.models.knn.KNN'>
# 0.7373866213151927 5
# <class 'pyod.models.lof.LOF'>
# 0.638888888888889 5
# <class 'pyod.models.cof.COF'>
# 0.6215986394557824
# semantic/Pima/Pima_withoutdupl_norm_35.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6704925373134328
# <class 'pyod.models.knn.KNN'>
# 0.7360373134328357 67
# <class 'pyod.models.lof.LOF'>
# 0.6717089552238806 69
# <class 'pyod.models.cof.COF'>
# 0.5822462686567164
# semantic/SpamBase/SpamBase_withoutdupl_norm_40.arff
# <class 'pyod.models.abod.ABOD'>
# 0.40259940365347063
# <class 'pyod.models.knn.KNN'>
# 0.6504956282371211 39
# <class 'pyod.models.lof.LOF'>
# 0.47803057218356315 2
# <class 'pyod.models.cof.COF'>
# 0.43488839235228927
# semantic/Stamps/Stamps_withoutdupl_norm_09.arff
# <class 'pyod.models.abod.ABOD'>
# 0.7036225075686398
# <class 'pyod.models.knn.KNN'>
# 0.919093851132686 63
# <class 'pyod.models.lof.LOF'>
# 0.8232592128614677 69
# <class 'pyod.models.cof.COF'>
# 0.6150955214531788
# semantic/Wilt/Wilt_withoutdupl_norm_05.arff
# <class 'pyod.models.abod.ABOD'>
# 0.586005694137154
# <class 'pyod.models.knn.KNN'>
# 0.5613313841120268 2
# <class 'pyod.models.lof.LOF'>
# 0.6699183067021256 5
# <class 'pyod.models.cof.COF'>
# 0.6211872054205183

# %%
df.head()
# Out:
#                                 semantic/Annthyroid/Annthyroid_withoutdupl_norm_07.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.677865
# <class 'pyod.models.knn.KNN'>                              [0.6728163431040994, 2]
# <class 'pyod.models.lof.LOF'>                             [0.7021573204078677, 11]
# <class 'pyod.models.cof.COF'>                                             0.665676
#
#                                 semantic/Arrhythmia/Arrhythmia_withoutdupl_norm_46.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.724833
# <class 'pyod.models.knn.KNN'>                             [0.7606040108228554, 43]
# <class 'pyod.models.lof.LOF'>                             [0.7550135285691548, 48]
# <class 'pyod.models.cof.COF'>                                             0.719143
#
#                                 semantic/Cardiotocography/Cardiotocography_withoutdupl_norm_22.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.484097
# <class 'pyod.models.knn.KNN'>                             [0.5576807887828659, 69]
# <class 'pyod.models.lof.LOF'>                             [0.6023545251885496, 69]
# <class 'pyod.models.cof.COF'>                                             0.567474
#
#                                 semantic/HeartDisease/HeartDisease_withoutdupl_norm_44.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.628722
# <class 'pyod.models.knn.KNN'>                             [0.6998888888888889, 68]
# <class 'pyod.models.lof.LOF'>                             [0.6398333333333334, 69]
# <class 'pyod.models.cof.COF'>                                                0.527
#
#                                 semantic/Hepatitis/Hepatitis_withoutdupl_norm_16.arff  \
# <class 'pyod.models.abod.ABOD'>                                            0.64868
# <class 'pyod.models.knn.KNN'>                             [0.7898966704936854, 25]
# <class 'pyod.models.lof.LOF'>                             [0.8036739380022963, 50]
# <class 'pyod.models.cof.COF'>                                             0.510907
#
#                                 semantic/InternetAds/InternetAds_withoutdupl_norm_19.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.657151
# <class 'pyod.models.knn.KNN'>                              [0.722096574522501, 13]
# <class 'pyod.models.lof.LOF'>                             [0.7026641658050825, 69]
# <class 'pyod.models.cof.COF'>                                             0.678556
#
#                                 semantic/PageBlocks/PageBlocks_withoutdupl_norm_09.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.701307
# <class 'pyod.models.knn.KNN'>                             [0.8728066159906518, 69]
# <class 'pyod.models.lof.LOF'>                             [0.8105893596430995, 69]
# <class 'pyod.models.cof.COF'>                                             0.686132
#
#                                 semantic/Parkinson/Parkinson_withoutdupl_norm_75.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.625142
# <class 'pyod.models.knn.KNN'>                              [0.7373866213151927, 5]
# <class 'pyod.models.lof.LOF'>                               [0.638888888888889, 5]
# <class 'pyod.models.cof.COF'>                                             0.621599
#
#                                 semantic/Pima/Pima_withoutdupl_norm_35.arff  \
# <class 'pyod.models.abod.ABOD'>                                    0.670493
# <class 'pyod.models.knn.KNN'>                      [0.7360373134328357, 67]
# <class 'pyod.models.lof.LOF'>                      [0.6717089552238806, 69]
# <class 'pyod.models.cof.COF'>                                      0.582246
#
#                                 semantic/SpamBase/SpamBase_withoutdupl_norm_40.arff  \
# <class 'pyod.models.abod.ABOD'>                                           0.402599
# <class 'pyod.models.knn.KNN'>                             [0.6504956282371211, 39]
# <class 'pyod.models.lof.LOF'>                             [0.47803057218356315, 2]
# <class 'pyod.models.cof.COF'>                                             0.434888
#
#                                 semantic/Stamps/Stamps_withoutdupl_norm_09.arff  \
# <class 'pyod.models.abod.ABOD'>                                        0.703623
# <class 'pyod.models.knn.KNN'>                           [0.919093851132686, 63]
# <class 'pyod.models.lof.LOF'>                          [0.8232592128614677, 69]
# <class 'pyod.models.cof.COF'>                                          0.615096
#
#                                 semantic/Wilt/Wilt_withoutdupl_norm_05.arff
# <class 'pyod.models.abod.ABOD'>                                    0.586006
# <class 'pyod.models.knn.KNN'>                       [0.5613313841120268, 2]
# <class 'pyod.models.lof.LOF'>                       [0.6699183067021256, 5]
# <class 'pyod.models.cof.COF'>                                      0.621187

# %%
df.to_csv("sematicManhattan.csv")

# %%
differentModels = [
    abod.ABOD,
    knn.KNN,
    lof.LOF,
    cof.COF,
]

literature_dataset_paths = [
    "literature/ALOI/ALOI_withoutdupl_norm.arff",
    "literature/Glass/Glass_withoutdupl_norm.arff",
    "literature/Ionosphere/Ionosphere_withoutdupl_norm.arff",
    "literature/KDDCup99/KDDCup99_withoutdupl_norm_idf.arff",
    "literature/Lymphography/Lymphography_withoutdupl_norm_idf.arff",
    "literature/PenDigits/PenDigits_withoutdupl_norm_v10.arff",
    "literature/Shuttle/Shuttle_withoutdupl_norm_v10.arff",
    "literature/Waveform/Waveform_withoutdupl_norm_v10.arff",
    "literature/WBC/WBC_withoutdupl_norm_v10.arff",
    "literature/WDBC/WDBC_withoutdupl_norm_v10.arff",
    "literature/WPBC/WPBC_withoutdupl_norm.arff"
]

# %%
dicts = {}
for t in literature_dataset_paths:
    print(t)
    dicts[t] = {}
    arff_file = arff.loadarff(f'./{t}') # import the attribute-relation file format
    df4 = pd.DataFrame(arff_file[0])
    X = df4.drop(columns=['outlier','id']).values
    #get outlier values
    y = df4['outlier'].values
    le = LabelEncoder()
    #encoded the variables as 0=non-outlier, 1=outlier
    y = le.fit_transform(y)
    for z in differentModels:
        print(z)
        arr = []
        arr2 = []
        if z == abod.ABOD or z == cof.COF:
            clf = z(contamination=0.1)
            clf.fit(X)
            print(roc_auc_score(y, clf.decision_scores_))
            dicts[t][z] = roc_auc_score(y, clf.decision_scores_)
        else:
            for kn in range(2,70):
                clf = z(p=2, n_neighbors=kn)
                clf.fit(X)
                arr += [roc_auc_score(y, clf.decision_scores_)]
                arr2 += [kn]

            print(max(arr),arr.index(max(arr))+2)
            dicts[t][z] = [max(arr),arr.index(max(arr))+2]

df = pd.DataFrame.from_dict(dicts)
# Out:
# literature/ALOI/ALOI_withoutdupl_norm.arff
# <class 'pyod.models.abod.ABOD'>
# 0.7678683744580881
# <class 'pyod.models.knn.KNN'>
# 0.7406193743861774 2
# <class 'pyod.models.lof.LOF'>
# 0.7825832086863649 9
# <class 'pyod.models.cof.COF'>
# 0.8038778674371896
# literature/Glass/Glass_withoutdupl_norm.arff
# <class 'pyod.models.abod.ABOD'>
# 0.8493224932249321
# <class 'pyod.models.knn.KNN'>
# 0.8747967479674799 9
# <class 'pyod.models.lof.LOF'>
# 0.8682926829268293 12
# <class 'pyod.models.cof.COF'>
# 0.8552845528455285
# literature/Ionosphere/Ionosphere_withoutdupl_norm.arff
# <class 'pyod.models.abod.ABOD'>
# 0.9262433862433862
# <class 'pyod.models.knn.KNN'>
# 0.9273721340388007 2
# <class 'pyod.models.lof.LOF'>
# 0.9054673721340388 6
# <class 'pyod.models.cof.COF'>
# 0.8588359788359788
# literature/KDDCup99/KDDCup99_withoutdupl_norm_idf.arff
# <class 'pyod.models.abod.ABOD'>
# 0.7750839020725064
# <class 'pyod.models.knn.KNN'>
# 0.9788655479723665 69
# <class 'pyod.models.lof.LOF'>
# 0.6847878446350677 41
# <class 'pyod.models.cof.COF'>
# 0.5555720785590549
# literature/Lymphography/Lymphography_withoutdupl_norm_idf.arff
# <class 'pyod.models.abod.ABOD'>
# 0.9741784037558685
# <class 'pyod.models.knn.KNN'>
# 1.0 15
# <class 'pyod.models.lof.LOF'>
# 1.0 62
# <class 'pyod.models.cof.COF'>
# 0.9917840375586855
# literature/PenDigits/PenDigits_withoutdupl_norm_v10.arff
# <class 'pyod.models.abod.ABOD'>
# 0.9593369212022745
# <class 'pyod.models.knn.KNN'>
# 0.9921151502843217 13
# <class 'pyod.models.lof.LOF'>
# 0.9657900081234768 68
# <class 'pyod.models.cof.COF'>
# 0.9243399675060926
# literature/Shuttle/Shuttle_withoutdupl_norm_v10.arff
# <class 'pyod.models.abod.ABOD'>
# 0.3096153846153846
# <class 'pyod.models.knn.KNN'>
# 0.8176153846153846 4
# <class 'pyod.models.lof.LOF'>
# 0.8371538461538462 6
# <class 'pyod.models.cof.COF'>
# 0.35507692307692307
# literature/Waveform/Waveform_withoutdupl_norm_v10.arff
# <class 'pyod.models.abod.ABOD'>
# 0.6468321866586898
# <class 'pyod.models.knn.KNN'>
# 0.7732366138199223 69
# <class 'pyod.models.lof.LOF'>
# 0.7512384086150165 69
# <class 'pyod.models.cof.COF'>
# 0.6830720909362848
# literature/WBC/WBC_withoutdupl_norm_v10.arff
# <class 'pyod.models.abod.ABOD'>
# 0.9380281690140845
# <class 'pyod.models.knn.KNN'>
# 0.9971830985915494 40
# <class 'pyod.models.lof.LOF'>
# 0.9929577464788732 62
# <class 'pyod.models.cof.COF'>
# 0.7596244131455399
# literature/WDBC/WDBC_withoutdupl_norm_v10.arff
# <class 'pyod.models.abod.ABOD'>
# 0.9246498599439776
# <class 'pyod.models.knn.KNN'>
# 0.9859943977591036 68
# <class 'pyod.models.lof.LOF'>
# 0.9879551820728292 67
# <class 'pyod.models.cof.COF'>
# 0.9462184873949581
# literature/WPBC/WPBC_withoutdupl_norm.arff
# <class 'pyod.models.abod.ABOD'>
# 0.4772439058757222
# <class 'pyod.models.knn.KNN'>
# 0.540932788502184 13
# <class 'pyod.models.lof.LOF'>
# 0.5251514724531492 24
# <class 'pyod.models.cof.COF'>
# 0.47428490911652815

# %%
df.to_csv("LitEucliStateofArt.csv")
